# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import PDEsolver as pde

# %%
import matplotlib.animation as animation
# %matplotlib notebook

# %%
x0 = 0
xn = 2
dx = 1/16
Nx = int((xn-x0)/dx)
x = np.linspace(x0,xn,Nx+1)

t0 = 0
tn = 1
dt = 1/800
Nt = int((tn-t0)/dt)
t = np.linspace(t0,tn,Nt+1)

# %%
r = dt/(dx)**2
print(r)
# Out:
# 0.32

# %%
def f(x):
    return 1 + 2*x + np.sin(2*np.pi*x)

def g1(t):
    return 1

def g2(t):
    return 2

# %%
time,x,heat = pde.FTCS(x0,xn,dx,t0,tn,dt,f,g1,g2,"DN")
# Out:
#  r is less than 1/2

# %%
plt.clf()
fig=plt.figure(figsize=(5,4))
pc=plt.pcolormesh(heat, cmap=plt.cm.jet)
fig.colorbar(pc)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="500">

# %%
fig1,ax1 = plt.subplots()

def animate(i):
    ax1.clear()
    ax1.plot(x,heat[i,:],"r^--")
    ax1.set_title("time = %1.2f sec"%(i))
    ax1.grid()
    ax1.set_xlabel("x")
    ax1.set_ylabel("Temp(x)")

ani = animation.FuncAnimation(fig1,animate,Nt,interval=1, blit=False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ani.save('/tmp/animation.gif', writer='imagemagick', fps=30)
# Out:
# MovieWriter stderr:
# convert-im6.q16: no images defined `/tmp/animation.gif' @ error/convert.c/ConvertImageCommand/3229.
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~/miniconda3/envs/a330/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     235         try:
# --> 236             yield self
#     237         finally:
#
# ~/miniconda3/envs/a330/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1094                         frame_number += 1
# -> 1095                 writer.grab_frame(**savefig_kwargs)
#    1096
#
# ~/miniconda3/envs/a330/lib/python3.8/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
# ...

# %%
ani.save('Explicit.gif',writer='imagemagick')
# Out:
# MovieWriter stderr:
# convert-im6.q16: no images defined `Explicit.gif' @ error/convert.c/ConvertImageCommand/3229.
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~/miniconda3/envs/a330/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     235         try:
# --> 236             yield self
#     237         finally:
#
# ~/miniconda3/envs/a330/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1094                         frame_number += 1
# -> 1095                 writer.grab_frame(**savefig_kwargs)
#    1096
#
# ~/miniconda3/envs/a330/lib/python3.8/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
# ...
